# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with:
#
# mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.list_database_names()
# Out:
# ['Health_information',
#  'admin',
#  'autosaurus',
#  'classDB',
#  'config',
#  'local',
#  'met',
#  'petsitly_marketing',
#  'testinghealth_data',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'West Cottage',
#  'AddressLine2': 'South Foreland Lighthouse',
#  'AddressLine3': 'The Front',
#  'AddressLine4': 'St Margarets Bay',
#  'BusinessName': 'Mrs Knotts Tea Room',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.492467848017,
#  'FHRSID': 429991,
#  'LocalAuthorityBusinessID': 'PI/000055200',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6HP',
#  'RatingDate': '2019-05-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67a493f985278f3d2dbf568a'),
#  'geocode': {'latitude': '51.14061', 'longitude': '1.371894'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/429991',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_halal_restaurant={
        "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True

}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_halal_restaurant)
# Out:
# InsertOneResult(ObjectId('67a49429b101b5c21c8bae3a'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
query= {"BusinessName":"Penang Flavours"}
pprint(establishments.find_one(query))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67a49429b101b5c21c8bae3a'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query= {"BusinessType":'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID':1,'BusinessType':1 }
results=establishments.find(query,fields)
for i in results:
    pprint(i)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf568a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf568b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf568d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf568e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf568f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5690')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5691')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5692')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5698')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5699')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf569b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56bb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf56fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5700')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5706')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf570a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf570d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf570f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5712')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5714')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5715')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5717')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf571b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5721')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5725')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5728')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5729')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf572e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5734')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5736')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5737')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5739')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf573a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5744')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5745')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf574b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5752')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5754')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5755')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf575a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf575f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5760')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5765')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5766')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5776')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5777')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5778')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5781')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5786')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5789')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf578b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf578c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf578e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf579c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf579e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57a8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57b3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf57f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5802')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5804')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5805')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5807')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5808')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf580c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf580e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf580f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5813')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5817')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5820')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5821')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5822')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5828')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf582a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf582e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5833')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5835')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf583e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5843')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5844')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf584b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf584e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5850')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5853')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5857')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5859')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf585d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5864')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf586b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5878')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5880')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf58a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf58aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf58ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf58b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf58b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf58b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf58c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf58d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf58ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf58f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf58ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5902')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5904')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5906')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5914')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf591e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5922')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5928')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf592b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5932')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5933')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5934')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5939')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf593c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf593d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf593f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5942')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf594b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf594c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf595d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5961')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5962')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5963')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf596d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5972')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf597c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf597f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5983')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5985')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5995')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5998')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf599d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf59fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a01')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a02')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a08')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a13')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a16')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a17')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a18')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a19')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a1a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a1c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a21')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a22')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a23')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a29')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a2a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a2c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a3c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a3f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a40')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a43')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a46')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a47')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a4b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a4c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a54')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a55')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a56')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a58')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a59')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a5c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a61')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a63')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a64')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a65')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a66')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a6d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a74')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a76')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a7a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a7f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a80')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a81')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a83')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a84')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a85')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a8a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a8b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a8e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a93')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a98')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5a9b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5aa4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5aa7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5abe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5ac3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5ac5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5acc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5acd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5acf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5ad4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5ae7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5aee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5af2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5af4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5af5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5afa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b00')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b04')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b06')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b07')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b08')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b09')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b0d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b0e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b12')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b14')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b18')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b20')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b27')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b28')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b2a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b2b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b2c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b2d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b2f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b30')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b31')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b32')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b34')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b3b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b3c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b42')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b45')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b46')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b47')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b48')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b49')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b50')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b52')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b5b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b5c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b5d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b5f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b61')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b63')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b6a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b6d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b76')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b77')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b7c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b7e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b80')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b85')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b89')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b8c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b90')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b99')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5b9f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5ba0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5ba2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5ba5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5baa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bb3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bb4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bb8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bbc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bbd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bc2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bc7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bcb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bcc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bd9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bda')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bdb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bde')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5be1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5be2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5be3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5be4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5be6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5be7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5be9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bf2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bf3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bf7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bf8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bf9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bfa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bfb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bfc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bfd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bfe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5bff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c01')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c03')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c07')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c08')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c11')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c12')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c14')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c15')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c16')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c18')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c1f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c21')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c24')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c26')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c2b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c2d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c2e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c35')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c38')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c42')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c4c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c57')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c5c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c5d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c60')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c63')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c6c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c70')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c78')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c79')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c7b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c7e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c7f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c81')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c85')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c8a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c8c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c98')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5c9d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5ca0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493f985278f3d2dbf5ca1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfefd9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfefda')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfefdb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfefdc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfefdd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfefdf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfefe0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfefe5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfefe8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfefea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfeff0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfeff8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfeffa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfeffb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbfeffe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff000')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff001')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff002')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff004')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff006')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff007')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff00b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff00d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff00e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff010')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff012')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff014')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff016')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff017')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff01a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff01e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff020')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff022')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff024')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff025')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff026')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff02b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff02c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff02f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff037')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff03b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff03c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff043')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff048')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff049')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff050')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff053')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff054')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff055')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff05c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff080')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff086')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff08b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff090')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff092')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff093')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff096')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff098')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff09a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff09b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff09c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff09d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff0fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff10a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff10b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff10c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff112')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff119')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff11a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff11d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff125')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff126')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff12a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff12c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff130')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff136')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff13a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff13c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff13d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff141')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff142')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff143')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff145')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff148')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff14a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff14b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff150')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff151')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff152')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff153')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff154')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff157')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff158')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff15b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff15c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff162')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff163')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff164')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff166')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff167')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff16a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff16c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff16d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff172')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff175')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff17b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff17c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff189')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff18b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff18d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff191')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff193')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff199')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff19b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff1a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff1af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff1b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff1b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff1c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff1c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff1ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff1d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff1d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff1db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff1df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a493fb85278f3d2dbff1ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('67a49429b101b5c21c8bae3a')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
query={"BusinessName":"Penang Flavours"}
field={'$set': {'BusinessTypeID':1}}
establishments.update_one(query,field)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName': 'Penang Flavours'}
fields = {'BusinessName': 1, 'BusinessTypeID': 1, '_id': 0}
pprint(establishments.find_one(query, fields))
# Out:
# {'BusinessName': 'Penang Flavours', 'BusinessTypeID': 1}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': 'Dover'}
establishments.count_documents(query)
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {'LocalAuthorityName': 'Dover'}
establishments.delete_many(query)
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
query = {'LocalAuthorityName': 'Dover'}
establishments.count_documents(query)
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67a493f985278f3d2dbf596f'),
#  'geocode': {'latitude': '51.086058', 'longitude': '1.196408'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({},[{'$set':{'geocode.longitude':{'$toDouble':'$geocode.longitude'},
                                        'geocode.latitude':{'$toDouble':'$geocode.latitude'}}}])
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set':{'RatingValue':{'$toInt':'$RatingValue'}}}])
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers

query = {}
fields = {'RatingValue': 1, 'geocode.longitude': 1,'geocode.latitude':1, '_id': 0}
results=establishments.find_one(query, fields)
print(f"{results}\n RatingValue:{type(results['RatingValue'])}\nLongitude:{type(results['geocode']['longitude'])}\nLatitude:{type(results['geocode']['latitude'])}")
# Out:
# {'RatingValue': 4, 'geocode': {'longitude': 1.196408, 'latitude': 51.086058}}
#  RatingValue:<class 'int'>
# Longitude:<class 'float'>
# Latitude:<class 'float'>
